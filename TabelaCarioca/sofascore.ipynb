# %%
import requests

url = "https://sofascores.p.rapidapi.com/v1/search/multi"

querystring = {"group":"teams","query":"Flamengo"}

headers = {
	"X-RapidAPI-Key": "b7f139b5f2mshd8d0f0154205bb9p1b60bbjsn69a174306bd1",
	"X-RapidAPI-Host": "sofascores.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': [{'name': 'Flamengo', 'slug': 'flamengo', 'shortName': 'Flamengo', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 13, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'tournament': {'name': 'Brasileirão Série A', 'slug': 'brasileirao-serie-a', 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 13, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'uniqueTournament': {'name': 'Brasileirão Série A', 'slug': 'brasileirao-serie-a', 'primaryColorHex': '#C7FF00', 'secondaryColorHex': '#969696', 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 13, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'userCount': 291881, 'hasPerformanceGraphFeature': True, 'id': 325, 'country': {}, 'displayInverseHomeAwayTeams': False}, 'priority': 442, 'id': 83}, 'primaryUniqueTournament': {'name': 'Brasileirão Série A', 'slug': 'brasileirao-serie-a', 'primaryColorHex': '#C7FF00', 'secondaryColorHex': '#969696', 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 13, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'userCount': 291881, 'hasPerformanceGraphFeature': True, 'id': 325, 'country': {}, 'displayInverseHomeAwayTeams': False}, 'userCount': 304432, 'nameCode': 'FLA', 'disabled': False, 'national': False, 'type': 0, 'id': 5981, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'teamColors': {'primary': '#ff0000', 'secondary': '#000000', 'text': '#000000'}}, {'name': 'Flamengo U20', 'slug': 'flamengo-u20', 'shortName': 'Flamengo', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 13, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'tournament': {'name': 'U20 Campeonato Brasileiro', 'slug': 'u20-campeonato-brasileiro', 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 13, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'uniqueTournament': {'name': 'U20 Campeonato Brasileiro', 'slug': 'u20-campeonato-brasileiro', 'primaryColorHex': '#debe04', 'secondaryColorHex': '#384ba9', 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 13, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'userCount': 6292, 'id': 9233, 'country': {}, 'hasPerformanceGraphFeature': False, 'displayInverseHomeAwayTeams': False}, 'priority': 0, 'id': 73456}, 'primaryUniqueTournament': {'name': 'U20 Carioca, Serie A', 'slug': 'u20-carioca-serie-a', 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 13, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'userCount': 455, 'hasPerformanceGraphFeature': False, 'id': 20102, 'country': {}, 'displayInverseHomeAwayTeams': False}, 'userCount': 19797, 'nameCode': 'FLA', 'national': False, 'type': 0, 'id': 199329, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'teamColors': {'primary': '#ff0000', 'secondary': '#000000', 'text': '#000000'}}, {'name': 'Flamengo', 'slug': 'flamengo', 'shortName': 'Flamengo', 'gender': 'M', 'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2}, 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2}, 'id': 263, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'tournament': {'name': 'NBB', 'slug': 'nbb' ...

# %%
import requests

url = "https://sofascores.p.rapidapi.com/v1/unique-tournaments/data"

querystring = {"unique_tournament_id":"18017"}

headers = {
	"X-RapidAPI-Key": "b7f139b5f2mshd8d0f0154205bb9p1b60bbjsn69a174306bd1",
	"X-RapidAPI-Host": "sofascores.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'name': 'Campeonato Carioca', 'slug': 'campeonato-carioca', 'logo': {'md5': 'c16c3fb4e0cc85423c734332095b9e37', 'id': 1397232}, 'category': {'name': 'Brazil', 'slug': 'brazil', 'sport': {'name': 'Futsal', 'slug': 'futsal', 'id': 29}, 'id': 202, 'country': {'alpha2': 'BR', 'name': 'Brazil'}, 'flag': 'brazil', 'alpha2': 'BR'}, 'userCount': 1379, 'mostTitlesTeams': [], 'linkedUniqueTournaments': [], 'hasStandingsGroups': True, 'hasRounds': True, 'hasPlayoffSeries': False, 'upperDivisions': [], 'lowerDivisions': [], 'crowdsourcingEnabled': False, 'hasPerformanceGraphFeature': False, 'periodLength': {}, 'id': 18017, 'country': {}, 'startDateTimestamp': 1698343293, 'endDateTimestamp': 1702749693, 'displayInverseHomeAwayTeams': False}}

# %%
import requests

url = "https://sofascores.p.rapidapi.com/v1/teams/player-statistics/result"

querystring = {"team_id":"5981","unique_tournament_id":"92","season_id":"56974"}

headers = {
	"X-RapidAPI-Key": "b7f139b5f2mshd8d0f0154205bb9p1b60bbjsn69a174306bd1",
	"X-RapidAPI-Host": "sofascores.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'goals': [{'statistics': {'goals': 1, 'id': 1263392, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Pedro', 'slug': 'pedro', 'shortName': 'Pedro', 'position': 'F', 'userCount': 14642, 'id': 840219, 'fieldTranslations': {'nameTranslation': {'ar': 'بيدرو'}, 'shortNameTranslation': {}}}}, {'statistics': {'goals': 1, 'id': 1263384, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Everton', 'slug': 'everton', 'shortName': 'Everton', 'position': 'F', 'userCount': 6240, 'id': 386198, 'fieldTranslations': {'nameTranslation': {'ar': 'إيفرتون'}, 'shortNameTranslation': {}}}}, {'statistics': {'goals': 1, 'id': 1263386, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Léo Pereira', 'slug': 'leo-pereira', 'shortName': 'Léo Pereira', 'position': 'D', 'userCount': 1677, 'id': 358548}}, {'statistics': {'goals': 1, 'id': 1263381, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Guillermo Varela', 'slug': 'guillermo-varela', 'shortName': 'G. Varela', 'position': 'D', 'userCount': 1366, 'id': 311456, 'fieldTranslations': {'nameTranslation': {'ar': 'فاريلا'}, 'shortNameTranslation': {}}}}], 'assists': [{'statistics': {'id': 1263383, 'assists': 1, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Giorgian De Arrascaeta', 'slug': 'giorgian-de-arrascaeta', 'shortName': 'G. De Arrascaeta', 'position': 'M', 'userCount': 15903, 'id': 333587, 'fieldTranslations': {'nameTranslation': {'ar': 'أراسكايتا'}, 'shortNameTranslation': {}}}}, {'statistics': {'id': 1263390, 'assists': 1, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Gerson', 'slug': 'gerson', 'shortName': 'Gerson', 'position': 'M', 'userCount': 8424, 'id': 611876, 'fieldTranslations': {'nameTranslation': {'ar': 'جيرسون'}, 'shortNameTranslation': {}}}}, {'statistics': {'id': 1263385, 'assists': 1, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Luiz Araújo', 'slug': 'luiz-araujo', 'shortName': 'L. Araújo', 'position': 'M', 'userCount': 2132, 'id': 840451}}], 'goalsAssistsSum': [{'statistics': {'goalsAssistsSum': 1, 'id': 1263392, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Pedro', 'slug': 'pedro', 'shortName': 'Pedro', 'position': 'F', 'userCount': 14642, 'id': 840219, 'fieldTranslations': {'nameTranslation': {'ar': 'بيدرو'}, 'shortNameTranslation': {}}}}, {'statistics': {'goalsAssistsSum': 1, 'id': 1263384, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Everton', 'slug': 'everton', 'shortName': 'Everton', 'position': 'F', 'userCount': 6240, 'id': 386198, 'fieldTranslations': {'nameTranslation': {'ar': 'إيفرتون'}, 'shortNameTranslation': {}}}}, {'statistics': {'goalsAssistsSum': 1, 'id': 1263386, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Léo Pereira', 'slug': 'leo-pereira', 'shortName': 'Léo Pereira', 'position': 'D', 'userCount': 1677, 'id': 358548}}, {'statistics': {'goalsAssistsSum': 1, 'id': 1263381, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Guillermo Varela', 'slug': 'guillermo-varela', 'shortName': 'G. Varela', 'position': 'D', 'userCount': 1366, 'id': 311456, 'fieldTranslations': {'nameTranslation': {'ar': 'فاريلا'}, 'shortNameTranslation': {}}}}, {'statistics': {'goalsAssistsSum': 1, 'id': 1263383, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Giorgian De Arrascaeta', 'slug': 'giorgian-de-arrascaeta', 'shortName': 'G. De Arrascaeta', 'position': 'M', 'userCount': 15903, 'id': 333587, 'fieldTranslations': {'nameTranslation': {'ar': 'أراسكايتا'}, 'shortNameTranslation': {}}}}, {'statistics': {'goalsAssistsSum': 1, 'id': 1263390, 'type': 'overall', 'appearances': 1}, 'playedEnough': True, 'player': {'name': 'Gerson', 'slug': 'gerson', 'shortName': 'Gerson', 'position': 'M', 'userCount': 84 ...
